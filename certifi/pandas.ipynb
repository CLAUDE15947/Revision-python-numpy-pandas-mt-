# %%
import numpy as np
import pandas as pd

# %%
my_index=['usa','canada','mexico']

# %%
my_data=[2004,2005,2008]

# %%
my_ser = pd.Series(data=my_data,index=my_index)

# %%
my_ser
# Out:
# usa       2004
# canada    2005
# mexico    2008
# dtype: int64

# %%
my_ser['usa']
# Out:
# np.int64(2004)

# %%
ages={'sam':5,'patou':10}

# %%
pd.Series(ages)
# Out:
# sam       5
# patou    10
# dtype: int64

# %%
q1={'Japan':80,'China':450,'India':200,'usa':250}
q2={'Brazil':100,'China':500,'India':210,'usa':260}

# %%
sales_Q1 = pd.Series(q1)
sales_Q2 = pd.Series(q2)

# %%
sales_Q1['usa']
# Out:
# np.int64(250)
